# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../../Documents/GitHub/sci-comp/Sci comp/app/mesonet_QC_data.xlsx')

# %%
df
# Out:
#     station_name County  latitude  longitude  ring_number  core_number  \
# 0      Manhattan  Riley  39.20856  -96.59169            1            1
# 1      Manhattan  Riley  39.20856  -96.59169            2            1
# 2      Manhattan  Riley  39.20856  -96.59169            3            1
# 3      Manhattan  Riley  39.20856  -96.59169            4            1
# 4      Manhattan  Riley  39.20856  -96.59169            5            2
# ..           ...    ...       ...        ...          ...          ...
# 315         Hays  Ellis  38.84941  -99.34457           68            1
# 316         Hays  Ellis  38.84941  -99.34457           69            2
# 317         Hays  Ellis  38.84941  -99.34457           70            2
# 318         Hays  Ellis  38.84941  -99.34457           71            2
# 319         Hays  Ellis  38.84941  -99.34457           72            2
#
#      nominal_depth sampling_date_1  Ksat_cm_per_day  Ksat_cm_per_hr  ...  \
# ...

# %%
plt.scatter(df['clay'],df['sand'])
plt.show()
